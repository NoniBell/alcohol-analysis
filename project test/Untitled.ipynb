# %%
import pandas as pd
df = pd.read_csv("cleaned_happiness.csv")

# %%
df
# Out:
#      Country name  Year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008     3.723590            7.370100        0.450662
# 1     Afghanistan  2009     4.401778            7.539972        0.552308
# 2     Afghanistan  2010     4.758381            7.646709        0.539075
# 3     Afghanistan  2011     3.831719            7.619532        0.521104
# 4     Afghanistan  2012     3.782938            7.705479        0.520637
# ...           ...   ...          ...                 ...             ...
# 1944     Zimbabwe  2016     3.735400            7.984372        0.768425
# 1945     Zimbabwe  2017     3.638300            8.015738        0.754147
# 1946     Zimbabwe  2018     3.616480            8.048798        0.775388
# 1947     Zimbabwe  2019     2.693523            7.950132        0.759162
# 1948     Zimbabwe  2020     3.159802            7.828757        0.717243
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
df.rename(columns={"Country name": "country_name", "Year": "year","Life Ladder": "life_ladder"})
# Out:
#      country_name  year  life_ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008     3.723590            7.370100        0.450662
# 1     Afghanistan  2009     4.401778            7.539972        0.552308
# 2     Afghanistan  2010     4.758381            7.646709        0.539075
# 3     Afghanistan  2011     3.831719            7.619532        0.521104
# 4     Afghanistan  2012     3.782938            7.705479        0.520637
# ...           ...   ...          ...                 ...             ...
# 1944     Zimbabwe  2016     3.735400            7.984372        0.768425
# 1945     Zimbabwe  2017     3.638300            8.015738        0.754147
# 1946     Zimbabwe  2018     3.616480            8.048798        0.775388
# 1947     Zimbabwe  2019     2.693523            7.950132        0.759162
# 1948     Zimbabwe  2020     3.159802            7.828757        0.717243
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
df.columns.to_list()
# Out:
# ['Country name',
#  'Year',
#  'Life Ladder',
#  'Log GDP per capita',
#  'Social support',
#  'Healthy life expectancy at birth',
#  'Freedom to make life choices',
#  'Generosity',
#  'Perceptions of corruption',
#  'Positive Effect',
#  'Negative Effect']

# %%
df =df.rename(columns={"Country name": "country_name", "Year": "year","Life Ladder": "life_ladder",
                       'Log GDP per capita':'log_gdp_per_capita',
 'Social support':'social_support',
 'Healthy life expectancy at birth':'healthy_life_expectancy_at_birth',
 'Freedom to make life choices':'freedom_to_make_life_choices',
 'Generosity':'generosity',
 'Perceptions of corruption':'perceptions_of_corruption',
 'Positive Effect':'positive_effect',
 'Negative Effect':'negative_effect'})

# %%
df = df.rename(columns={'perceptions of corruption':'perceptions_of_corruption'})

# %%
df
# Out:
#      country_name  year  life_ladder  log_gdp_per_capita  social_support  \
# 0     Afghanistan  2008     3.723590            7.370100        0.450662
# 1     Afghanistan  2009     4.401778            7.539972        0.552308
# 2     Afghanistan  2010     4.758381            7.646709        0.539075
# 3     Afghanistan  2011     3.831719            7.619532        0.521104
# 4     Afghanistan  2012     3.782938            7.705479        0.520637
# ...           ...   ...          ...                 ...             ...
# 1944     Zimbabwe  2016     3.735400            7.984372        0.768425
# 1945     Zimbabwe  2017     3.638300            8.015738        0.754147
# 1946     Zimbabwe  2018     3.616480            8.048798        0.775388
# 1947     Zimbabwe  2019     2.693523            7.950132        0.759162
# 1948     Zimbabwe  2020     3.159802            7.828757        0.717243
#
#       healthy_life_expectancy_at_birth  freedom_to_make_life_choices  \
# ...

# %%
df.to_csv(r'happiness.csv', index = False)

# %%
df2 = pd.read_csv("wine-consumption-per-person.csv")

# %%
df2.columns.tolist()
# Out:
# ['Entity',
#  'Code',
#  'Year',
#  'Indicator:Alcohol, recorded per capita (15+) consumption (in litres of pure alcohol) - Beverage Types:Wine']

# %%
df2 = df2.rename(columns = {'Entity':'country_name',
 'Code':'code',
 'Year':'year',
 'Indicator:Alcohol, recorded per capita (15+) consumption (in litres of pure alcohol) - Beverage Types:Wine':"wine_consumption"})

# %%
df2
# Out:
#            entity code  year  wine_consumption
# 0     Afghanistan  AFG  1961              0.00
# 1     Afghanistan  AFG  1962              0.00
# 2     Afghanistan  AFG  1963              0.00
# 3     Afghanistan  AFG  1964              0.00
# 4     Afghanistan  AFG  1965              0.00
# ...           ...  ...   ...               ...
# 8948     Zimbabwe  ZWE  2010              0.10
# 8949     Zimbabwe  ZWE  2011              0.12
# 8950     Zimbabwe  ZWE  2012              0.08
# 8951     Zimbabwe  ZWE  2013              0.05
# 8952     Zimbabwe  ZWE  2014              0.05
#
# [8953 rows x 4 columns]

# %%
df2 = df2.rename(columns = {"entity":"country_name"})

# %%
df2
# Out:
#      country_name code  year  wine_consumption
# 0     Afghanistan  AFG  1961              0.00
# 1     Afghanistan  AFG  1962              0.00
# 2     Afghanistan  AFG  1963              0.00
# 3     Afghanistan  AFG  1964              0.00
# 4     Afghanistan  AFG  1965              0.00
# ...           ...  ...   ...               ...
# 8948     Zimbabwe  ZWE  2010              0.10
# 8949     Zimbabwe  ZWE  2011              0.12
# 8950     Zimbabwe  ZWE  2012              0.08
# 8951     Zimbabwe  ZWE  2013              0.05
# 8952     Zimbabwe  ZWE  2014              0.05
#
# [8953 rows x 4 columns]

# %%
df2.to_csv(r'wine.csv', index = False)

# %%
df3 = pd.read_csv("spirits-consumption-per-person.csv")

# %%
df3.columns.tolist()
# Out:
# ['Entity',
#  'Code',
#  'Year',
#  'Indicator:Alcohol, recorded per capita (15+) consumption (in litres of pure alcohol) - Beverage Types:Spirits']

# %%
df3 = df3.rename(columns = {'Entity':"country_name",
 'Code': 'code',
 'Year':'year',
 'Indicator:Alcohol, recorded per capita (15+) consumption (in litres of pure alcohol) - Beverage Types:Spirits':"spirits_consumption"})

# %%
df3
# Out:
#      country_name code  year  spirits_consumption
# 0     Afghanistan  AFG  1961                 0.00
# 1     Afghanistan  AFG  1962                 0.00
# 2     Afghanistan  AFG  1963                 0.00
# 3     Afghanistan  AFG  1964                 0.00
# 4     Afghanistan  AFG  1965                 0.00
# ...           ...  ...   ...                  ...
# 8948     Zimbabwe  ZWE  2010                 0.34
# 8949     Zimbabwe  ZWE  2011                 0.32
# 8950     Zimbabwe  ZWE  2012                 0.44
# 8951     Zimbabwe  ZWE  2013                 0.43
# 8952     Zimbabwe  ZWE  2014                 0.43
#
# [8953 rows x 4 columns]

# %%
df2.to_csv(r'spirits.csv', index = False)

# %%
df3.to_csv(r'spirits.csv', index = False)

# %%
df4 = pd.read_csv("beer-consumption-per-person.csv")

# %%
df4.columns.tolist()
# Out:
# ['Entity',
#  'Code',
#  'Year',
#  'Indicator:Alcohol, recorded per capita (15+) consumption (in litres of pure alcohol) - Beverage Types:Beer']

# %%
df4= df4.rename(columns = {'Entity':'country_name',
 'Code':'code',
 'Year':'year',
 'Indicator:Alcohol, recorded per capita (15+) consumption (in litres of pure alcohol) - Beverage Types:Beer':'beer_consumption'})

# %%
df4
# Out:
#      country_name code  year  beer_consumption
# 0     Afghanistan  AFG  1961              0.00
# 1     Afghanistan  AFG  1962              0.00
# 2     Afghanistan  AFG  1963              0.00
# 3     Afghanistan  AFG  1964              0.00
# 4     Afghanistan  AFG  1965              0.00
# ...           ...  ...   ...               ...
# 8947     Zimbabwe  ZWE  2010              1.67
# 8948     Zimbabwe  ZWE  2011              2.05
# 8949     Zimbabwe  ZWE  2012              2.07
# 8950     Zimbabwe  ZWE  2013              2.12
# 8951     Zimbabwe  ZWE  2014              2.23
#
# [8952 rows x 4 columns]

# %%
df4.to_csv(r'beer.csv', index = False)
